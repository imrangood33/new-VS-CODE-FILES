# %% [markdown]
# ##step1 (important libraries)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (2.3.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\imran\miniconda3\envs\python_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import numpy as np  #for numerical operations
import matplotlib.pyplot as plt  #for plotting and accuracy/loss graphs
import tensorflow as tf #for building and training the CNN
from tensorflow.keras import layers, models #for creating layers and models

# %% [markdown]
# ##step2: load and preprocess the CIFAR-10 Dataset

# %%
#load the CIFAR-10 Dataset from tensorflow datasets
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Normalize pixel values from [0, 255] to [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0
# Define class names for CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 659s 4us/step

# %% [markdown]
# ##step3: visualize some dataset
